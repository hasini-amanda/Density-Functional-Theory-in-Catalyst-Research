# %% [markdown]
# <a href="https://colab.research.google.com/github/hasini-amanda/Density-Functional-Theory-in-Catalyst-Research/blob/main/HandsOn_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get install -y python3-dev libopenblas-dev liblapack-dev libfftw3-dev libxc-dev
# !pip install gpaw
# !gpaw test
# !wget https://wiki.fysik.dtu.dk/gpaw-files/gpaw-setups-24.1.0.tar.gz
# !tar -xzf gpaw-setups-24.1.0.tar.gz

import os
import gzip
import shutil

# Define the path to the setup files
setup_path = '/content/gpaw-setups-24.1.0'

# Uncompress all .gz files in the setup directory
for filename in os.listdir(setup_path):
    if filename.endswith('.gz'):
        filepath = os.path.join(setup_path, filename)
        with gzip.open(filepath, 'rb') as f_in:
            with open(filepath[:-3], 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)

# Set the GPAW_SETUP_PATH environment variable
os.environ['GPAW_SETUP_PATH'] = setup_path
# Verify the environment variable
print("GPAW_SETUP_PATH:", os.environ['GPAW_SETUP_PATH'])

# Import ASE and GPAW and run your calculation
from ase import Atoms
from gpaw import GPAW

# Define the atomic structure
d = 0.74
a = 10.0

h2 = Atoms('H2',
              positions=[(0, 0, 0),
                         (0, 0, d)],
              cell=(a, a, a))
h2.center()
# Initialize GPAW calculator without specifying the 'setups' parameter
calc = GPAW(mode='fd', nbands=2, txt='h2.txt')
h2.calc = calc

# Run the calculation
print("Forces on atoms:", h2.get_forces())
print("Energies on atoms:", h2.get_total_energy())

# !sudo apt-get install povray  ## visulization program

import shutil
from ase.io import write  # Import the write function from ASE
from PIL import Image
from IPython.display import display  # Import display for Jupyter Notebooks


def visual(structure, max_size=(200, 200), stretch_y=2.0, rotation='15z,-60x', png_save_path='./'):
    renderer = write('./temp.pov', structure, rotation=rotation)
    renderer.render()
    image_path = './temp.png'
    img = Image.open(image_path)

    # Calculate new size with stretch factor
    new_size = (max_size[0], int(max_size[1] * stretch_y))
    img = img.resize(new_size, Image.LANCZOS)
    display(img)

    # Move files to output directory
    files = ['./temp.ini', './temp.pov', './temp.png']
    destination = './output/'

    # Ensure destination directory exists
    os.makedirs(destination, exist_ok=True)

    for file in files:
        # Remove the file in the destination directory if it exists
        if os.path.isfile(os.path.join(destination, os.path.basename(file))):
            os.remove(os.path.join(destination, os.path.basename(file)))

        if file == './temp.png':
            new_file_name = png_save_path + f'temp.png'
        else:
            new_file_name = os.path.basename(file)
        shutil.move(file, os.path.join(destination, new_file_name))
visual(h2)
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,618 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,205 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,968 kB]
# Get:14 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,637 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,600 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,411 kB]
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,869 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Fetched 36.2 MB in 7s (5,526 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# liblapack-dev is already the newest version (3.10.0-2ubuntu1).
# libopenblas-dev is already the newest version (0.3.20+ds-1).
# The following additional packages will be installed:
#   javascript-common libfftw3-bin libfftw3-double3 libfftw3-long3
#   libfftw3-quad3 libfftw3-single3 libjs-sphinxdoc libjs-underscore
#   libpython3.10 libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib
#   libxc9 python3.10 python3.10-dev python3.10-minimal
# Suggested packages:
#   apache2 | lighttpd | httpd libfftw3-doc python3.10-venv python3.10-doc
#   binfmt-support
# The following NEW packages will be installed:
#   javascript-common libfftw3-bin libfftw3-dev libfftw3-double3 libfftw3-long3
#   libfftw3-quad3 libfftw3-single3 libjs-sphinxdoc libjs-underscore libxc-dev
#   libxc9 python3-dev python3.10-dev
# The following packages will be upgraded:
#   libpython3.10 libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib
#   python3.10 python3.10-minimal
# 6 upgraded, 13 newly installed, 0 to remove and 44 not upgraded.
# Need to get 29.5 MB of archives.
# After this operation, 67.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-dev amd64 3.10.12-1~22.04.13 [4,763 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10 amd64 3.10.12-1~22.04.13 [1,949 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10 amd64 3.10.12-1~22.04.13 [508 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-stdlib amd64 3.10.12-1~22.04.13 [1,850 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-minimal amd64 3.10.12-1~22.04.13 [2,272 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-minimal amd64 3.10.12-1~22.04.13 [815 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 javascript-common all 11+nmu1 [5,936 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-long3 amd64 3.3.8-2ubuntu8 [335 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-quad3 amd64 3.3.8-2ubuntu8 [614 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-single3 amd64 3.3.8-2ubuntu8 [800 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-bin amd64 3.3.8-2ubuntu8 [35.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-dev amd64 3.3.8-2ubuntu8 [2,101 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-underscore all 1.13.2~dfsg-2 [118 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-sphinxdoc all 4.3.2-1 [139 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxc9 amd64 5.1.7-1ubuntu1 [3,900 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxc-dev amd64 5.1.7-1ubuntu1 [8,038 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-dev amd64 3.10.12-1~22.04.13 [508 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-dev amd64 3.10.6-1~22.04.1 [26.0 kB]
# Fetched 29.5 MB in 4s (7,938 kB/s)
# (Reading database ... 117528 files and directories currently installed.)
# Preparing to unpack .../00-libpython3.10-dev_3.10.12-1~22.04.13_amd64.deb ...
# Unpacking libpython3.10-dev:amd64 (3.10.12-1~22.04.13) over (3.10.12-1~22.04.12) ...
# Preparing to unpack .../01-libpython3.10_3.10.12-1~22.04.13_amd64.deb ...
# Unpacking libpython3.10:amd64 (3.10.12-1~22.04.13) over (3.10.12-1~22.04.12) ...
# Preparing to unpack .../02-python3.10_3.10.12-1~22.04.13_amd64.deb ...
# Unpacking python3.10 (3.10.12-1~22.04.13) over (3.10.12-1~22.04.12) ...
# Preparing to unpack .../03-libpython3.10-stdlib_3.10.12-1~22.04.13_amd64.deb ...
# Unpacking libpython3.10-stdlib:amd64 (3.10.12-1~22.04.13) over (3.10.12-1~22.04.12) ...
# Preparing to unpack .../04-python3.10-minimal_3.10.12-1~22.04.13_amd64.deb ...
# Unpacking python3.10-minimal (3.10.12-1~22.04.13) over (3.10.12-1~22.04.12) ...
# Preparing to unpack .../05-libpython3.10-minimal_3.10.12-1~22.04.13_amd64.deb ...
# Unpacking libpython3.10-minimal:amd64 (3.10.12-1~22.04.13) over (3.10.12-1~22.04.12) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../06-javascript-common_11+nmu1_all.deb ...
# Unpacking javascript-common (11+nmu1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../07-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-long3:amd64.
# Preparing to unpack .../08-libfftw3-long3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../09-libfftw3-quad3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../10-libfftw3-single3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../11-libfftw3-bin_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-bin (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../12-libfftw3-dev_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../13-libjs-underscore_1.13.2~dfsg-2_all.deb ...
# Unpacking libjs-underscore (1.13.2~dfsg-2) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../14-libjs-sphinxdoc_4.3.2-1_all.deb ...
# Unpacking libjs-sphinxdoc (4.3.2-1) ...
# Selecting previously unselected package libxc9:amd64.
# Preparing to unpack .../15-libxc9_5.1.7-1ubuntu1_amd64.deb ...
# Unpacking libxc9:amd64 (5.1.7-1ubuntu1) ...
# Selecting previously unselected package libxc-dev.
# Preparing to unpack .../16-libxc-dev_5.1.7-1ubuntu1_amd64.deb ...
# Unpacking libxc-dev (5.1.7-1ubuntu1) ...
# Selecting previously unselected package python3.10-dev.
# Preparing to unpack .../17-python3.10-dev_3.10.12-1~22.04.13_amd64.deb ...
# Unpacking python3.10-dev (3.10.12-1~22.04.13) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../18-python3-dev_3.10.6-1~22.04.1_amd64.deb ...
# Unpacking python3-dev (3.10.6-1~22.04.1) ...
# Setting up javascript-common (11+nmu1) ...
# Setting up libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libfftw3-long3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libfftw3-quad3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libpython3.10-minimal:amd64 (3.10.12-1~22.04.13) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libjs-underscore (1.13.2~dfsg-2) ...
# Setting up libxc9:amd64 (5.1.7-1ubuntu1) ...
# Setting up libfftw3-bin (3.3.8-2ubuntu8) ...
# Setting up libxc-dev (5.1.7-1ubuntu1) ...
# Setting up python3.10-minimal (3.10.12-1~22.04.13) ...
# Setting up libpython3.10-stdlib:amd64 (3.10.12-1~22.04.13) ...
# Setting up libjs-sphinxdoc (4.3.2-1) ...
# Setting up libfftw3-dev:amd64 (3.3.8-2ubuntu8) ...
# Setting up libpython3.10:amd64 (3.10.12-1~22.04.13) ...
# Setting up python3.10 (3.10.12-1~22.04.13) ...
# Setting up libpython3.10-dev:amd64 (3.10.12-1~22.04.13) ...
# Setting up python3.10-dev (3.10.12-1~22.04.13) ...
# Setting up python3-dev (3.10.6-1~22.04.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Collecting gpaw
#   Downloading gpaw-25.7.0.tar.gz (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ase>=3.25.0 (from gpaw)
#   Downloading ase-3.27.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from gpaw) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from gpaw) (1.16.3)
# Collecting gpaw-data (from gpaw)
#   Downloading gpaw_data-1.0.1-py3-none-any.whl.metadata (756 bytes)
# Requirement already satisfied: matplotlib>=3.5.2 in /usr/local/lib/python3.12/dist-packages (from ase>=3.25.0->gpaw) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase>=3.25.0->gpaw) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase>=3.25.0->gpaw) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase>=3.25.0->gpaw) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase>=3.25.0->gpaw) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase>=3.25.0->gpaw) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase>=3.25.0->gpaw) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase>=3.25.0->gpaw) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.2->ase>=3.25.0->gpaw) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->ase>=3.25.0->gpaw) (1.17.0)
# Downloading ase-3.27.0-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 75.5 MB/s eta 0:00:00
# Downloading gpaw_data-1.0.1-py3-none-any.whl (71.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 MB 11.2 MB/s eta 0:00:00
# Building wheels for collected packages: gpaw
#   Building wheel for gpaw (setup.py) ... done
#   Created wheel for gpaw: filename=gpaw-25.7.0-cp312-cp312-linux_x86_64.whl size=2940310 sha256=f84247ea3834cef98d8e93b59dc7a234cd9e274f5df23b6a6600c4de022483e2
#   Stored in directory: /root/.cache/pip/wheels/59/7c/28/cb3306302de78987f064930ee3bac389062c0f87bfda50de21
# Successfully built gpaw
# Installing collected packages: gpaw-data, ase, gpaw
# Successfully installed ase-3.27.0 gpaw-25.7.0 gpaw-data-1.0.1
#  -------------------------------------------------------------------------------------------------
# | python-3.12.12    /usr/bin/python3                                                              |
# | gpaw-25.7.0       /usr/local/lib/python3.12/dist-packages/gpaw/                                 |
# | ase-3.27.0        /usr/local/lib/python3.12/dist-packages/ase/                                  |
# | numpy-2.0.2       /usr/local/lib/python3.12/dist-packages/numpy/                                |
# | scipy-1.16.3      /usr/local/lib/python3.12/dist-packages/scipy/                                |
# | gpaw_data-1.0.1   /usr/local/lib/python3.12/dist-packages/gpaw_data/                            |
# | libxc-5.1.7       yes                                                                           |
# | _gpaw             /usr/local/lib/python3.12/dist-packages/_gpaw.cpython-312-x86_64-linux-gnu.so |
# | MPI enabled       yes                                                                           |
# | OpenMP enabled    no                                                                            |
# | GPU enabled       no                                                                            |
# | GPU-aware MPI     no                                                                            |
# | cupy-fake         /usr/local/lib/python3.12/dist-packages/gpaw/gpu/cpupy/__init__.py            |
# | MAGMA             no                                                                            |
# | scalapack         no                                                                            |
# | Elpa              no                                                                            |
# | FFTW              no                                                                            |
# | libvdwxc          no                                                                            |
# | PAW-datasets (1)  /usr/local/lib/python3.12/dist-packages/gpaw_data/setups                      |
#  -------------------------------------------------------------------------------------------------
# Doing a test calculation (cores: 1): ... Done
#
# Test parallel calculation with "gpaw -P 4 test".
# --2026-01-17 12:28:18--  https://wiki.fysik.dtu.dk/gpaw-files/gpaw-setups-24.1.0.tar.gz
# Resolving wiki.fysik.dtu.dk (wiki.fysik.dtu.dk)... 130.225.86.28
# Connecting to wiki.fysik.dtu.dk (wiki.fysik.dtu.dk)|130.225.86.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53598132 (51M) [application/x-gzip]
# Saving to: ‘gpaw-setups-24.1.0.tar.gz’
#
# gpaw-setups-24.1.0. 100%[===================>]  51.11M  11.1MB/s    in 4.8s
#
# 2026-01-17 12:28:24 (10.6 MB/s) - ‘gpaw-setups-24.1.0.tar.gz’ saved [53598132/53598132]
#
# GPAW_SETUP_PATH: /content/gpaw-setups-24.1.0
# Forces on atoms: [[-6.33825912e-31 -6.33825912e-31 -8.85932373e-01]
#  [-3.16912956e-31  0.00000000e+00  8.85932373e-01]]
# Energies on atoms: -6.64951951886836
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-povray libboost-thread1.74.0 libilmbase25 libopenexr25 libsdl1.2debian
#   povray-includes
# Suggested packages:
#   povray-doc povray-examples
# The following NEW packages will be installed:
#   fonts-povray libboost-thread1.74.0 libilmbase25 libopenexr25 libsdl1.2debian
#   povray povray-includes
# 0 upgraded, 7 newly installed, 0 to remove and 44 not upgraded.
# Need to get 3,010 kB of archives.
# After this operation, 11.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-povray all 1:3.7.0.10-1 [70.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-thread1.74.0 amd64 1.74.0-14ubuntu3 [262 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsdl1.2debian amd64 1.2.15+dfsg2-6 [177 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 povray amd64 1:3.7.0.10-1 [1,312 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 povray-includes all 1:3.7.0.10-1 [233 kB]
# Fetched 3,010 kB in 3s (1,199 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 7.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-povray.
# (Reading database ... 117736 files and directories currently installed.)
# Preparing to unpack .../0-fonts-povray_1%3a3.7.0.10-1_all.deb ...
# Unpacking fonts-povray (1:3.7.0.10-1) ...
# Selecting previously unselected package libboost-thread1.74.0:amd64.
# Preparing to unpack .../1-libboost-thread1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libilmbase25:amd64.
# Preparing to unpack .../2-libilmbase25_2.5.7-2_amd64.deb ...
# Unpacking libilmbase25:amd64 (2.5.7-2) ...
# Selecting previously unselected package libopenexr25:amd64.
# Preparing to unpack .../3-libopenexr25_2.5.7-1_amd64.deb ...
# Unpacking libopenexr25:amd64 (2.5.7-1) ...
# Selecting previously unselected package libsdl1.2debian:amd64.
# Preparing to unpack .../4-libsdl1.2debian_1.2.15+dfsg2-6_amd64.deb ...
# Unpacking libsdl1.2debian:amd64 (1.2.15+dfsg2-6) ...
# Selecting previously unselected package povray.
# Preparing to unpack .../5-povray_1%3a3.7.0.10-1_amd64.deb ...
# Unpacking povray (1:3.7.0.10-1) ...
# Selecting previously unselected package povray-includes.
# Preparing to unpack .../6-povray-includes_1%3a3.7.0.10-1_all.deb ...
# Unpacking povray-includes (1:3.7.0.10-1) ...
# Setting up libilmbase25:amd64 (2.5.7-2) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libsdl1.2debian:amd64 (1.2.15+dfsg2-6) ...
# Setting up fonts-povray (1:3.7.0.10-1) ...
# Setting up libboost-thread1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up povray (1:3.7.0.10-1) ...
# Setting up povray-includes (1:3.7.0.10-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# <PIL.Image.Image image mode=RGBA size=200x400>

# %%
# !apt-get update
# !apt-get install -y python3-dev libopenblas-dev liblapack-dev libfftw3-dev libxc-dev
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Ign:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,341 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,153 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,583 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,108 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,314 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,590 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,441 kB]
# Fetched 21.8 MB in 8s (2,856 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# liblapack-dev is already the newest version (3.10.0-2ubuntu1).
# libopenblas-dev is already the newest version (0.3.20+ds-1).
# python3-dev is already the newest version (3.10.6-1~22.04.1).
# python3-dev set to manually installed.
# The following additional packages will be installed:
#   libfftw3-bin libfftw3-double3 libfftw3-long3 libfftw3-quad3 libfftw3-single3 libxc9
# Suggested packages:
#   libfftw3-doc
# The following NEW packages will be installed:
#   libfftw3-bin libfftw3-dev libfftw3-double3 libfftw3-long3 libfftw3-quad3 libfftw3-single3
#   libxc-dev libxc9
# 0 upgraded, 8 newly installed, 0 to remove and 56 not upgraded.
# Need to get 16.6 MB of archives.
# After this operation, 65.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-long3 amd64 3.3.8-2ubuntu8 [335 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-quad3 amd64 3.3.8-2ubuntu8 [614 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-single3 amd64 3.3.8-2ubuntu8 [800 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-bin amd64 3.3.8-2ubuntu8 [35.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-dev amd64 3.3.8-2ubuntu8 [2,101 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxc9 amd64 5.1.7-1ubuntu1 [3,900 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxc-dev amd64 5.1.7-1ubuntu1 [8,038 kB]
# Fetched 16.6 MB in 2s (8,166 kB/s)
# Selecting previously unselected package libfftw3-double3:amd64.
# (Reading database ... 123599 files and directories currently installed.)
# Preparing to unpack .../0-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-long3:amd64.
# Preparing to unpack .../1-libfftw3-long3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../2-libfftw3-quad3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../3-libfftw3-single3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../4-libfftw3-bin_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-bin (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../5-libfftw3-dev_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libxc9:amd64.
# Preparing to unpack .../6-libxc9_5.1.7-1ubuntu1_amd64.deb ...
# Unpacking libxc9:amd64 (5.1.7-1ubuntu1) ...
# Selecting previously unselected package libxc-dev.
# Preparing to unpack .../7-libxc-dev_5.1.7-1ubuntu1_amd64.deb ...
# Unpacking libxc-dev (5.1.7-1ubuntu1) ...
# Setting up libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libfftw3-long3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libfftw3-quad3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libxc9:amd64 (5.1.7-1ubuntu1) ...
# Setting up libfftw3-bin (3.3.8-2ubuntu8) ...
# Setting up libxc-dev (5.1.7-1ubuntu1) ...
# Setting up libfftw3-dev:amd64 (3.3.8-2ubuntu8) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link

# %%
# !apt-get update
# !apt-get install -y python3-dev libopenblas-dev liblapack-dev libfftw3-dev libxc-dev
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Ign:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,341 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,153 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,583 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,108 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,314 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,590 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,441 kB]
# Fetched 21.8 MB in 8s (2,856 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# liblapack-dev is already the newest version (3.10.0-2ubuntu1).
# libopenblas-dev is already the newest version (0.3.20+ds-1).
# python3-dev is already the newest version (3.10.6-1~22.04.1).
# python3-dev set to manually installed.
# The following additional packages will be installed:
#   libfftw3-bin libfftw3-double3 libfftw3-long3 libfftw3-quad3 libfftw3-single3 libxc9
# Suggested packages:
#   libfftw3-doc
# The following NEW packages will be installed:
#   libfftw3-bin libfftw3-dev libfftw3-double3 libfftw3-long3 libfftw3-quad3 libfftw3-single3
#   libxc-dev libxc9
# 0 upgraded, 8 newly installed, 0 to remove and 56 not upgraded.
# Need to get 16.6 MB of archives.
# After this operation, 65.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-long3 amd64 3.3.8-2ubuntu8 [335 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-quad3 amd64 3.3.8-2ubuntu8 [614 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-single3 amd64 3.3.8-2ubuntu8 [800 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-bin amd64 3.3.8-2ubuntu8 [35.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-dev amd64 3.3.8-2ubuntu8 [2,101 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxc9 amd64 5.1.7-1ubuntu1 [3,900 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxc-dev amd64 5.1.7-1ubuntu1 [8,038 kB]
# Fetched 16.6 MB in 2s (8,166 kB/s)
# Selecting previously unselected package libfftw3-double3:amd64.
# (Reading database ... 123599 files and directories currently installed.)
# Preparing to unpack .../0-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-long3:amd64.
# Preparing to unpack .../1-libfftw3-long3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../2-libfftw3-quad3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../3-libfftw3-single3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../4-libfftw3-bin_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-bin (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../5-libfftw3-dev_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package libxc9:amd64.
# Preparing to unpack .../6-libxc9_5.1.7-1ubuntu1_amd64.deb ...
# Unpacking libxc9:amd64 (5.1.7-1ubuntu1) ...
# Selecting previously unselected package libxc-dev.
# Preparing to unpack .../7-libxc-dev_5.1.7-1ubuntu1_amd64.deb ...
# Unpacking libxc-dev (5.1.7-1ubuntu1) ...
# Setting up libfftw3-single3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libfftw3-long3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libfftw3-quad3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libxc9:amd64 (5.1.7-1ubuntu1) ...
# Setting up libfftw3-bin (3.3.8-2ubuntu8) ...
# Setting up libxc-dev (5.1.7-1ubuntu1) ...
# Setting up libfftw3-dev:amd64 (3.3.8-2ubuntu8) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link

# %%
"""Bulk Cu(fcc) test"""
from ase import Atoms
from ase.visualize import view
from gpaw import GPAW, PW
from ase.build import bulk
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ase.build import fcc111
from ase.constraints import FixAtoms

name = 'Cu-fcc'
a0 = 3.614  # fcc lattice parameter
k = 4
element='Cu'

"""Surface Cu(fcc) test"""


# Initialize the parameters
N_layer = 4 # number of layers
size = 1 #  supercell size
vac = 7.5

surf = fcc111(element, (size, size, N_layer), a=a0, vacuum=vac)

median_z = np.median(surf.positions[:, 2])
constraint = FixAtoms(mask=[atom.position[2] < (median_z + 0.01) for atom in surf])
surf.set_constraint(constraint)

# Set up the GPAW calculator
calc = GPAW(mode=PW(400),
            kpts=(k, k, 1),
            xc='PBE',
            txt='slab.txt')
# Attach the calculator to the slab
surf.calc = calc

start_time = time.time()
E_slab = surf.get_potential_energy()
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time
print("Atomic numbers:", surf.get_atomic_numbers())
print("Chemical symbols:", surf.get_chemical_symbols())
print("Positions:", surf.get_positions())
# Print the energy and the elapsed time
print(f'Potential Energy: {e} eV')
print(f'Time taken: {elapsed_time:.2f} seconds')
print(surf)
visual(surf)
# Out:
# Atomic numbers: [29 29 29 29]
# Chemical symbols: ['Cu', 'Cu', 'Cu', 'Cu']
# Positions: [[ 0.00000000e+00  0.00000000e+00  7.50000000e+00]
#  [ 1.27774195e+00  7.37704661e-01  9.58654387e+00]
#  [-1.02785171e-17  1.47540932e+00  1.16730877e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.37596316e+01]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-169766001> in <cell line: 0>()
#      48 print("Positions:", surf.get_positions())
#      49 # Print the energy and the elapsed time
# ---> 50 print(f'Potential Energy: {e} eV')
#      51 print(f'Time taken: {elapsed_time:.2f} seconds')
#      52 print(surf)
#
# NameError: name 'e' is not defined
